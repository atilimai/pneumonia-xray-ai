# %% [markdown]
# # Class Distribution Chart
#
# Generates `artifacts/figures/class_distribution.png` showing NORMAL vs PNEUMONIA image counts for each split (train / val / test).
#
# **Prerequisite:** dataset must be present at `data/raw/chest_xray/`.

# %%
import sys, os
# Allow importing from src/ when running from the notebooks/ directory
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'src') if os.path.basename(os.getcwd()) == 'notebooks' else 'src')

from visualization.class_distribution import plot_class_distribution

plot_class_distribution(
    data_dir="../data/raw/chest_xray",
    output_path="../artifacts/figures/class_distribution.png",
    dpi=150,
)
